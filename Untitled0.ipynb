# %% [markdown]
# <a href="https://colab.research.google.com/github/mama56655/ML-Projects/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade kaggle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 7.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.7.4.5
#     Uninstalling kaggle-1.7.4.5:
#       Successfully uninstalled kaggle-1.7.4.5
# ...

# %%
import os
import kagglehub

# ۱. تزریق توکنِ تو به قلب سیستم
os.environ['KAGGLE_API_TOKEN'] = "KGAT_d2569947004882ae8fd2cd58d421f6c8"

# ۲. دانلود مستقیم و بی‌دردسر
print("Dar hale download... (Lotfan sabr konid)")
path = kagglehub.dataset_download("sethdowden/portland-maps-assessor-data")

# ۳. تاییدیه مسیر فایل
print("Tamam! File-ha inja hastand:", path)
# Out:
# Dar hale download... (Lotfan sabr konid)
# ...
# 100%|██████████| 45.2M/45.2M [00:00<00:00, 164MB/s]
# Extracting files...
# Tamam! File-ha inja hastand: /root/.cache/kagglehub/datasets/sethdowden/portland-maps-assessor-data/versions/581

# %% [markdown]
# # 1ㅣ**Import Libraries**

# %%
import pandas as pd
import glob

# %% [markdown]
# #**2ㅣData Check 💾**

# %%
file_list = glob.glob(path + '/*.csv')
file_path = file_list[0]

# لود کردن دیتا با متغیر درست (نه با کل لیست)
data = pd.read_csv(file_path)

# نمایش اسم تمام ستون‌ها
print(data.columns)
# Out:
# /tmp/ipython-input-2734031742.py:5: DtypeWarning: Columns (2,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
# Index(['address', 'city', 'state', 'zip_code', 'zip_code_string', 'county',
#        'neighborhood', 'property_id', 'state_id', 'parent_state_id',
#        'alt_account_number', 'owner', 'legal_description', 'square_feet',
#        'market_value', 'sale_date', 'sale_price', 'year_built',
#        'x_state_plane', 'y_state_plane', 'x_web_mercator', 'y_web_mercator',
#        'latitude', 'longitude', 'primary'],
#       dtype='object')

# %%
data
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3479 entries, 0 to 3478
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Area        3479 non-null   object
#  1   Room        3479 non-null   int64
#  2   Parking     3479 non-null   bool
#  3   Warehouse   3479 non-null   bool
#  4   Elevator    3479 non-null   bool
#  5   Address     3456 non-null   object
#  6   Price       3479 non-null   float64
#  7   Price(USD)  3479 non-null   float64
# dtypes: bool(3), float64(2), int64(1), object(2)
# memory usage: 146.2+ KB

# %%
data.describe()
# Out:
#               Room         Price    Price(USD)
# count  3479.000000  3.479000e+03  3.479000e+03
# mean      2.079908  5.359023e+09  1.786341e+05
# std       0.758275  8.099935e+09  2.699978e+05
# min       0.000000  3.600000e+06  1.200000e+02
# 25%       2.000000  1.418250e+09  4.727500e+04
# 50%       2.000000  2.900000e+09  9.666667e+04
# 75%       2.000000  6.000000e+09  2.000000e+05
# max       5.000000  9.240000e+10  3.080000e+06

# %%
data.isna().sum()
# Out:
# Area           0
# Room           0
# Parking        0
# Warehouse      0
# Elevator       0
# Address       23
# Price          0
# Price(USD)     0
# dtype: int64

# %%
data.isna().mean()
# Out:
# Area          0.000000
# Room          0.000000
# Parking       0.000000
# Warehouse     0.000000
# Elevator      0.000000
# Address       0.006611
# Price         0.000000
# Price(USD)    0.000000
# dtype: float64
